# %% [markdown]
# ### Test

# %%
import torch
import torch.utils.data as Data
from torchvision import transforms
from torchvision.datasets import FashionMNIST
from model import VGG16

# %%
def test_data_process():
    test_data = FashionMNIST(root='./data',
                              train=False,
                              transform=transforms.Compose([transforms.Resize(size=224), transforms.ToTensor()]),
                              download=True)

    test_dataloader = Data.DataLoader(dataset=test_data,
                                       batch_size=1,
                                       shuffle=True,
                                       num_workers=0)
    return test_dataloader

# %%
def test_model_process(model, test_dataloader):
    # 设定测试所用到的设备，有GPU用GPU没有GPU用CPU
    device = "cuda" if torch.cuda.is_available() else 'cpu'

    # 讲模型放入到训练设备中
    model = model.to(device)

    # 初始化参数
    test_corrects = 0.0
    test_num = 0

    # 只进行前向传播计算，不计算梯度，从而节省内存，加快运行速度
    with torch.no_grad():
        for test_data_x, test_data_y in test_dataloader:
            # 将特征放入到测试设备中
            test_data_x = test_data_x.to(device)
            # 将标签放入到测试设备中
            test_data_y = test_data_y.to(device)
            # 设置模型为评估模式
            model.eval()
            # 前向传播过程，输入为测试数据集，输出为对每个样本的预测值
            output= model(test_data_x)
            # 查找每一行中最大值对应的行标
            pre_lab = torch.argmax(output, dim=1)
            # 如果预测正确，则准确度test_corrects加1
            test_corrects += torch.sum(pre_lab == test_data_y.data)
            # 将所有的测试样本进行累加
            test_num += test_data_x.size(0)

    # 计算测试准确率
    test_acc = test_corrects.double().item() / test_num
    print("测试的准确率为：", test_acc)

# %%
if __name__ == "__main__":
    # 加载模型
    model = VGG16()
    model.load_state_dict(torch.load('best_VGG.pth'))
    # # 利用现有的模型进行模型的测试
    test_dataloader = test_data_process()
    test_model_process(model, test_dataloader)


    # 设定测试所用到的设备，有GPU用GPU没有GPU用CPU
    device = "cuda" if torch.cuda.is_available() else 'cpu'
    model = model.to(device)

    classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    with torch.no_grad():
        for b_x, b_y in test_dataloader:
            b_x = b_x.to(device)
            b_y = b_y.to(device)

            # 设置模型为验证模型
            model.eval()
            output = model(b_x)
            pre_lab = torch.argmax(output, dim=1)
            result = pre_lab.item()
            label = b_y.item()
            print("预测值：",  classes[result], "------", "真实值：", classes[label])
# Out:
# C:\Users\23017\AppData\Local\Temp\ipykernel_82552\3387399384.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_VGG.pth'))
# 测试的准确率为： 0.9181
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# ...
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Dress ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Dress
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Coat ------ 真实值： Coat
# 预测值： Dress ------ 真实值： Dress
# 预测值： Ankle boot ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Dress ------ 真实值： Dress
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Bag ------ 真实值： Bag
# 预测值： Coat ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Bag ------ 真实值： Bag
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Dress ------ 真实值： Dress
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Dress ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Bag ------ 真实值： Bag
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Coat ------ 真实值： Coat
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Shirt
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Coat ------ 真实值： Coat
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Dress ------ 真实值： Dress
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Bag ------ 真实值： Bag
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Coat ------ 真实值： Coat
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Bag ------ 真实值： Bag
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Coat ------ 真实值： Coat
# 预测值： T-shirt/top ------ 真实值： T-shirt/top
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Pullover ------ 真实值： Pullover
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Bag ------ 真实值： Bag
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Ankle boot ------ 真实值： Ankle boot
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Sandal ------ 真实值： Sandal
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Sneaker ------ 真实值： Sneaker
# 预测值： Trouser ------ 真实值： Trouser
# 预测值： Shirt ------ 真实值： Shirt
# 预测值： Trouser ------ 真实值： Trouser
